# %%
import pandas as pd
import numpy as np

# List of files to process
files = ["Final_West zone.xlsx", "Final_Central zone.xlsx", "FInal_South zone.xlsx", "Final_East zone.xlsx", "Final_North zone.xlsx"]

for file in files:
    # Load the Excel file
    df = pd.read_excel(file, sheet_name="Sheet1")

    # Identify rows where LON.1 (column J, index 9) ends with 0.875, 0.125, or 0.0
    fractional_part = df.iloc[:, 9] % 1
    mask = fractional_part.isin([0.25, 0.5, 0.75, 0.375, 0.625])

    # Columns I to M (9th to 13th column, index 8 to 12)
    cols_to_filter = df.columns[8:13]

    # Create a copy of the dataframe but only modify columns after the 8th
    df_filtered = df.copy()

    # Apply NaN only for columns I to M, without changing the first 8 columns
    df_filtered.loc[~mask, cols_to_filter] = np.nan

    # **Shift non-NaN values UP in columns I to M**
    for col in cols_to_filter:
        df_filtered[col] = df_filtered[col].dropna().reset_index(drop=True)

    # Save the filtered data with a new name
    output_file = f"Final_{file}"
    df_filtered.to_excel(output_file, index=False)

    print(f"Filtered file saved as '{output_file}'")
# Out:
# Filtered file saved as 'Final_Final_West zone.xlsx'
# Filtered file saved as 'Final_Final_Central zone.xlsx'
# Filtered file saved as 'Final_FInal_South zone.xlsx'
# Filtered file saved as 'Final_Final_East zone.xlsx'
